# %%
import torch

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import torch.nn as nn

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
url = 'https://gist.githubusercontent.com/noamross/e5d3e859aa0c794be10b/raw/b999fb4425b54c63cab088c0ce2c0d6ce961a563/cars.csv'
df = pd.read_csv(url)
df.head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
sns.scatterplot(x='wt',y='mpg',data=df);

# %%
sns.regplot(x='wt',y='mpg',data=df);

# %%
# coverting the data into tensor
X_list = df.wt.values
X_np = np.array(X_list, dtype=np.float32).reshape(-1,1)
X = torch.from_numpy(X_np)

# %%
y_list = df.mpg.values.tolist()
y = torch.tensor(y_list)

# %%
w = torch.rand(1, requires_grad=True, dtype=torch.float32)
b = torch.rand(1, requires_grad=True, dtype=torch.float32)

# %%
num_epochs = 1000
learning_rate = 0.001

for epoch in range(num_epochs):
    for i in range(len(X)):
        # forward pass
        y_pred = w*X[i] + b
        loss = torch.pow(y_pred-y[i],2)
        
        # backward pass
        loss.backward()

        # extracting loss
        loss_value = loss.data[0]

        # update the weights and bias 
        with torch.no_grad():
            w -= w.grad * learning_rate
            b -= b.grad * learning_rate
            w.grad.zero_()
            b.grad.zero_()

    print(loss_value)
# Out:
# tensor(161.1198)
# tensor(81.8355)
# tensor(54.4452)
# tensor(43.6410)
# tensor(38.9167)
# tensor(36.6462)
# tensor(35.4236)
# tensor(34.6624)
# tensor(34.1087)
# tensor(33.6499)
# tensor(33.2360)
# tensor(32.8443)
# tensor(32.4649)
# tensor(32.0930)
# tensor(31.7267)
# tensor(31.3651)
# tensor(31.0076)
# tensor(30.6540)
# tensor(30.3043)
# tensor(29.9582)
# tensor(29.6159)
# tensor(29.2772)
# tensor(28.9420)
# tensor(28.6104)
# tensor(28.2824)
# tensor(27.9579)
# tensor(27.6368)
# tensor(27.3190)
# tensor(27.0047)
# tensor(26.6937)
# tensor(26.3860)
# tensor(26.0816)
# tensor(25.7805)
# tensor(25.4825)
# tensor(25.1877)
# tensor(24.8961)
# tensor(24.6076)
# tensor(24.3222)
# tensor(24.0398)
# tensor(23.7604)
# tensor(23.4841)
# tensor(23.2107)
# tensor(22.9401)
# tensor(22.6725)
# tensor(22.4078)
# tensor(22.1459)
# tensor(21.8868)
# tensor(21.6306)
# tensor(21.3770)
# tensor(21.1262)
# tensor(20.8781)
# tensor(20.6326)
# tensor(20.3898)
# tensor(20.1496)
# tensor(19.9120)
# tensor(19.6769)
# tensor(19.4444)
# tensor(19.2144)
# tensor(18.9869)
# tensor(18.7618)
# tensor(18.5392)
# tensor(18.3190)
# tensor(18.1012)
# tensor(17.8857)
# tensor(17.6725)
# tensor(17.4617)
# tensor(17.2531)
# tensor(17.0468)
# tensor(16.8428)
# tensor(16.6410)
# tensor(16.4414)
# tensor(16.2439)
# tensor(16.0486)
# tensor(15.8554)
# tensor(15.6644)
# tensor(15.4754)
# tensor(15.2885)
# tensor(15.1036)
# tensor(14.9207)
# tensor(14.7399)
# tensor(14.5610)
# tensor(14.3841)
# tensor(14.2091)
# tensor(14.0360)
# tensor(13.8649)
# tensor(13.6956)
# tensor(13.5282)
# tensor(13.3626)
# tensor(13.1989)
# tensor(13.0369)
# tensor(12.8768)
# tensor(12.7183)
# tensor(12.5617)
# tensor(12.4068)
# tensor(12.2536)
# tensor(12.1020)
# tensor(11.9522)
# tensor(11.8040)
# tensor(11.6575)
# tensor(11.5126)
# tensor(11.3693)
# tensor(11.2276)
# tensor(11.0874)
# tensor(10.9488)
# tensor(10.8118)
# tensor(10.6763)
# tensor(10.5423)
# tensor(10.4098)
# tensor(10.2788)
# tensor(10.1493)
# tensor(10.0212)
# tensor(9.8945)
# tensor(9.7692)
# tensor(9.6454)
# tensor(9.5229)
# tensor(9.4018)
# tensor(9.2821)
# tensor(9.1637)
# tensor(9.0467)
# tensor(8.9310)
# tensor(8.8166)
# tensor(8.7035)
# tensor(8.5916)
# tensor(8.4810)
# tensor(8.3717)
# tensor(8.2637)
# tensor(8.1568)
# tensor(8.0511)
# tensor(7.9467)
# tensor(7.8434)
# tensor(7.7414)
# tensor(7.6404)
# tensor(7.5407)
# tensor(7.4420)
# tensor(7.3445)
# tensor(7.2481)
# tensor(7.1529)
# tensor(7.0587)
# tensor(6.9656)
# tensor(6.8735)
# tensor(6.7825)
# tensor(6.6926)
# tensor(6.6037)
# tensor(6.5159)
# tensor(6.4290)
# tensor(6.3431)
# tensor(6.2583)
# tensor(6.1744)
# tensor(6.0915)
# tensor(6.0095)
# tensor(5.9285)
# tensor(5.8485)
# tensor(5.7694)
# tensor(5.6912)
# tensor(5.6139)
# tensor(5.5375)
# tensor(5.4620)
# tensor(5.3874)
# tensor(5.3137)
# tensor(5.2408)
# tensor(5.1688)
# tensor(5.0976)
# tensor(5.0273)
# tensor(4.9578)
# tensor(4.8891)
# tensor(4.8212)
# tensor(4.7542)
# tensor(4.6879)
# tensor(4.6224)
# tensor(4.5577)
# tensor(4.4938)
# tensor(4.4306)
# tensor(4.3682)
# tensor(4.3065)
# tensor(4.2456)
# tensor(4.1854)
# tensor(4.1259)
# tensor(4.0671)
# tensor(4.0090)
# tensor(3.9517)
# tensor(3.8950)
# tensor(3.8390)
# tensor(3.7836)
# tensor(3.7290)
# tensor(3.6750)
# tensor(3.6217)
# tensor(3.5690)
# tensor(3.5170)
# tensor(3.4656)
# tensor(3.4148)
# tensor(3.3646)
# tensor(3.3151)
# tensor(3.2661)
# tensor(3.2178)
# tensor(3.1700)
# tensor(3.1229)
# tensor(3.0763)
# tensor(3.0303)
# tensor(2.9849)
# tensor(2.9400)
# tensor(2.8957)
# tensor(2.8519)
# tensor(2.8087)
# tensor(2.7661)
# tensor(2.7239)
# tensor(2.6823)
# tensor(2.6412)
# tensor(2.6006)
# tensor(2.5606)
# tensor(2.5210)
# tensor(2.4819)
# tensor(2.4434)
# tensor(2.4053)
# tensor(2.3677)
# tensor(2.3305)
# tensor(2.2939)
# tensor(2.2577)
# tensor(2.2220)
# tensor(2.1867)
# tensor(2.1519)
# tensor(2.1176)
# tensor(2.0837)
# tensor(2.0502)
# tensor(2.0171)
# tensor(1.9845)
# tensor(1.9523)
# tensor(0.7345)
# tensor(0.7351)
# tensor(0.7358)
# tensor(0.7364)
# tensor(0.7371)
# tensor(0.7377)
# tensor(0.7384)
# tensor(0.7390)
# tensor(0.7397)
# tensor(0.7403)
# tensor(0.7409)
# tensor(0.7416)
# tensor(0.7422)
# tensor(0.7428)
# tensor(0.7435)
# tensor(0.7441)
# tensor(0.7447)
# tensor(0.7453)
# tensor(0.7459)
# tensor(0.7466)
# tensor(0.7472)
# tensor(0.7478)
# tensor(0.7484)
# tensor(0.7490)
# tensor(0.7496)
# tensor(0.7502)
# tensor(0.7507)
# tensor(0.7513)
# tensor(0.7519)
# tensor(0.7525)
# tensor(0.7531)
# tensor(0.7537)
# tensor(0.7542)
# tensor(0.7548)
# tensor(0.7554)
# tensor(0.7560)
# tensor(0.7565)
# tensor(0.7571)
# tensor(0.7577)
# tensor(0.7582)
# tensor(0.7588)
# tensor(0.7593)
# tensor(0.7599)
# tensor(0.7605)
# tensor(0.7610)
# tensor(0.7615)
# tensor(0.7621)
# tensor(0.7626)
# tensor(0.7631)
# tensor(0.7637)
# tensor(0.7642)
# tensor(0.7647)
# tensor(0.7653)
# tensor(0.7658)
# tensor(0.7663)
# tensor(0.7668)
# tensor(0.7674)
# tensor(0.7679)
# tensor(0.7684)
# tensor(0.7689)
# tensor(0.7694)
# tensor(0.7699)
# tensor(0.7704)
# tensor(0.7709)
# tensor(0.7714)
# tensor(0.7719)
# tensor(0.7724)
# tensor(0.7729)
# tensor(0.7734)
# tensor(0.7739)
# tensor(0.7744)
# tensor(0.7748)
# tensor(0.7753)
# tensor(0.7758)
# tensor(0.7763)
# tensor(0.7767)
# tensor(0.7772)
# tensor(0.7777)
# tensor(0.7782)
# tensor(0.7786)
# tensor(0.7791)
# tensor(0.7796)
# tensor(0.7800)
# tensor(0.7805)
# tensor(0.7810)

# %%
print(f"Weights: {w.item()}, Bias: {b.item()}")
# Out:
# Weights: -5.230330944061279, Bias: 36.80861282348633

# %%
sns.regplot(x='wt',y='mpg',data=df);

# %%
y_pred = ((X * w) + b).detach().numpy()
y_pred
# Out:
# array([[23.105146],
#        [21.771412],
#        [24.674246],
#        [19.9931  ],
#        [18.816275],
#        [18.711668],
#        [18.136332],
#        [20.123857],
#        [20.33307 ],
#        [18.816275],
#        [18.816275],
#        [15.521166],
#        [17.299479],
#        [17.037962],
#        [ 9.349375],
#        [ 8.439299],
#        [ 8.852495],
#        [25.301884],
#        [28.36163 ],
#        [27.210957],
#        [23.915848],
#        [18.397848],
#        [18.842426],
#        [16.724142],
#        [16.69799 ],
#        [26.687923],
#        [25.615704],
#        [28.895123],
#        [20.228464],
#        [22.320595],
#        [18.136332],
#        [22.268293]], dtype=float32)

# %%
sns.scatterplot(x=X_list,y=y_list)
sns.lineplot(x=X_list,y=y_pred.reshape(-1));

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_np,y_list)
print(f"Slope: {reg.coef_}, Intercept: {reg.intercept_}")
# Out:
# Slope: [-5.3444715], Intercept: 37.285125732421875

# %%
import os
from torchviz import make_dot
os.environ['PATH'] += os.pathsep + 'C:/Program Files/Graphviz/bin' 
make_dot(loss)

# %%
class LinearRegressionClass(nn.Module):
    def __init__(self,input_size,output_size):
        super(LinearRegressionClass,self).__init__()
        self.linear = nn.Linear(input_size, output_size)
    
    def forward(self, x):
        out = self.linear(x)
        return out

# %%
# batches in simpler term
input_dim = 1
output_dim = 1
# 
model = LinearRegressionClass(input_dim,output_dim)

# %%
loss_fucn = nn.MSELoss()

# %%
LR = 0.02
optimizer = torch.optim.SGD(model.parameters(), lr=LR)

# %%
losses, slope, bias = [], [], []
epoches = 1000

for epoch in range(epoches):
    # set gradients to zero
    optimizer.zero_grad()

    # forward pass 
    y_pred = model(X)

    # compute losses 
    loss = loss_fucn(y_pred,y)
    loss.backward()

    # update weight
    optimizer.step()

    # get parameters 
    for name, param in model.named_parameters():
        if param.requires_grad:
            if name == 'linear.weight':
                slope.append(param.data.numpy()[0][0]) 
            if name == 'linear.bias':
                bias.append(param.data.numpy()[0])
    # storing losses
    losses.append(float(loss.data))

    if epoch % 100 == 0:
        print('Epoch: {}, Loss: {:.4f}'.format(epoch, loss.data))
# Out:
# C:\Users\naman\anaconda3\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([32])) that is different to the input size (torch.Size([32, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch: 0, Loss: 599.9208
# Epoch: 100, Loss: 51.7422
# Epoch: 200, Loss: 44.1923
# Epoch: 300, Loss: 40.0859
# Epoch: 400, Loss: 37.8524
# Epoch: 500, Loss: 36.6376
# Epoch: 600, Loss: 35.9769
# Epoch: 700, Loss: 35.6175
# Epoch: 800, Loss: 35.4221
# Epoch: 900, Loss: 35.3158

# %%
sns.scatterplot(x=range(epoches),y = losses)
sns.lineplot(x=range(epoches),y = losses);

# %%
sns.scatterplot(x=range(epoches),y = bias)
sns.lineplot(x=range(epoches),y = bias);

# %%
sns.scatterplot(x=range(epoches),y = slope)
sns.lineplot(x=range(epoches),y = slope);

# %%
y_pred = model(X).data.numpy().reshape(-1)

# %%
sns.scatterplot(x=X_list,y=y_list)
sns.lineplot(x=X_list,y=y_pred,color='red');

# %%
losses, slope, bias = [], [], []
epoches = 1000
BATCH_SIZE = 2
for epoch in range(epoches):
    for i in range(0,X.shape[0],BATCH_SIZE):
        
        # set gradients to zero
        optimizer.zero_grad()
    
        # forward pass 
        y_pred = model(X[i:i+BATCH_SIZE])
    
        # compute losses 
        loss = loss_fucn(y_pred,y[i:i+BATCH_SIZE])
        loss.backward()
    
        # update weight
        optimizer.step()
    
        # get parameters 
        for name, param in model.named_parameters():
            if param.requires_grad:
                if name == 'linear.weight':
                    slope.append(param.data.numpy()[0][0]) 
                if name == 'linear.bias':
                    bias.append(param.data.numpy()[0])
        # storing losses
        losses.append(float(loss.data))
    
        if epoch % 100 == 0:
            print('Epoch: {}, Loss: {:.4f}'.format(epoch, loss.data))
# Out:
# C:\Users\naman\anaconda3\Lib\site-packages\torch\nn\modules\loss.py:608: UserWarning: Using a target size (torch.Size([2])) that is different to the input size (torch.Size([2, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch: